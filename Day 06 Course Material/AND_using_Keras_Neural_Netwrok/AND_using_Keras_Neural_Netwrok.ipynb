# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense

# AND gate truth table
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
Y = np.array([[0], [0], [0], [1]])

# Create a sequential model
model = Sequential()

# Add a dense layer with one neuron and sigmoid activation function
model.add(Dense(units=1, input_dim=2, activation='sigmoid'))

# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X, Y, epochs=1000, verbose=0)

# Test the model
print("Predictions:")
print(model.predict(X))

# Evaluate the model
loss, accuracy = model.evaluate(X, Y)
print(f"Loss: {loss:.4f}, Accuracy: {accuracy * 100:.2f}%")
# Out:
# Predictions:
# 1/1 [==============================] - 0s 214ms/step
# [[0.31176502]
#  [0.39454198]
#  [0.4395174 ]
#  [0.53008854]]
# 1/1 [==============================] - 0s 231ms/step - loss: 0.1667 - accuracy: 1.0000
# Loss: 0.1667, Accuracy: 100.00%

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense

# AND gate truth table
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
Y = np.array([[0], [0], [0], [1]])

# Create a sequential model
model = Sequential()

# Add a dense layer with one neuron and sigmoid activation function
model.add(Dense(units=1, input_dim=2, activation='sigmoid'))

# Add an output layer with linear activation function
model.add(Dense(units=1, activation='linear'))

# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X, Y, epochs=1000, verbose=0)

# Test the model
print("Predictions:")
predictions = model.predict(X)
threshold = 0.5
binary_predictions = np.where(predictions >= threshold, 1, 0)
print(binary_predictions)

# Evaluate the model
loss, accuracy = model.evaluate(X, Y)
print(f"Loss: {loss:.4f}, Accuracy: {accuracy * 100:.2f}%")
# Out:
# Predictions:
# 1/1 [==============================] - 0s 52ms/step
# [[0]
#  [0]
#  [0]
#  [1]]
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0697 - accuracy: 1.0000
# Loss: 0.0697, Accuracy: 100.00%
